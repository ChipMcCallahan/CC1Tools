# %% [markdown]
# <a href="https://colab.research.google.com/github/ChipMcCallahan/CC1LevelImager/blob/main/cc1_levelset_displayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install git+https://github.com/ChipMcCallahan/CC1Tools.git

# %%
from cc1_tools import CC1LevelsetReader, CC1LevelImager
import IPython.display as ipd

# %%
reader = CC1LevelsetReader()
s = reader.import_and_read("JBLP1.dat")
# Out:
# Successfully retrieved https://bitbusters.club/gliderbot/sets/cc1/JBLP1.dat.

# %%
imager = CC1LevelImager()   
img = imager.save_png(s.levels[0], "temp.png")
display(ipd.Image("temp.png"))
